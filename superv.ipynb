# %% [markdown]
# <a href="https://colab.research.google.com/github/lincolngadea/API-REST-cadastro-de-usuario-Java/blob/master/superv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Leitura dos arquivos de dataset
df_supervisionado = pd.read_csv('iris_superv.csv')
df_nao_supervisionado = pd.read_csv('iris_n_superv.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-c4c3e1f8a225> in <cell line: 2>()
#       1 # Leitura dos arquivos de dataset
# ----> 2 df_supervisionado = pd.read_csv('iris_superv.csv')
#       3 df_nao_supervisionado = pd.read_csv('iris_n_superv.csv')
#
# ...

# %%
# exibe dataframe
df_supervisionado.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d6fe5881a236> in <cell line: 2>()
#       1 # exibe dataframe
# ----> 2 df_supervisionado.head()
#
# NameError: name 'df_supervisionado' is not defined

# %%
# exibe dataframe
df_nao_supervisionado.tail()
# Out:
#      Comp. Sepalas (cm)  Larg. Sepalas (cm)  Comp. Petalas (cm)  \
# 145                 6.7                 3.0                 5.2
# 146                 6.3                 2.5                 5.0
# 147                 6.5                 3.0                 5.2
# 148                 6.2                 3.4                 5.4
# 149                 5.9                 3.0                 5.1
#
#      Larg. Petalas (cm)
# 145                 2.3
# 146                 1.9
# 147                 2.0
# 148                 2.3
# 149                 1.8

# %%
df_movies = pd.read_csv('movies.csv')
df_ratings = pd.read_csv('ratings.csv')

# %%
df_ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
